# %% [markdown]
# ## Face & Facial Landmark Detection
#
# In this notebook has showed how detect a face using dlib and perform facial detection

# %%
import cv2
import dlib
import numpy as np
import matplotlib.pyplot as plt

sample = cv2.cvtColor(cv2.imread('resources/sample.jpg'), cv2.COLOR_BGR2GRAY)
plt.imshow(sample, cmap='gray')
plt.show()

# %% [markdown]
# DLib uses HOG and SVM in order to search in the image, it computes over a sliding window HOG and then uses SVM classifier in order to find if is contained a face in the current window.
#
# After that face has been detected we want to extract facial landmarks. This can be done with the implementation of dlib of 'One Millisecond Face Alignment with an Ensemble of Regression Trees'. Specifically are extracted 68 points as specified by https://ibug.doc.ic.ac.uk/resources/facial-point-annotations/ with a dlib pretrained model.

# %%
from face_recognition_cam.util import find_faces

# detect a face
faces = find_faces(sample, landmarks=True)

# draw a box around faces
sample_toshow = sample.copy()
sample_toshow = cv2.cvtColor(sample_toshow, cv2.COLOR_GRAY2RGB)
for face in faces:
    (top, left), (bottom, right) = face['rectangle']
    cv2.rectangle(
        sample_toshow,
        (left, top),
        (right, bottom),
        (255,0,0),
        2
    )
    for landmark in face['landmarks']:
        cv2.circle(sample_toshow, tuple(landmark[::-1]), 3, (255, 0, 0), 2)

plt.figure(figsize=(10, 10))
plt.imshow(sample_toshow)
plt.show()

# %% [markdown]
# Once we have all 68 landmark points through an homography the image is warped in order to obtain the correct orientation

# %%
from face_recognition_cam.util import warp_face

my_face = find_faces(sample, landmarks=True, relative=True)[0]

(rmin, cmin), (rmax, cmax) = my_face['rectangle']
face = sample[rmin:rmax, cmin:cmax]
face_warped, landmarks = warp_face(face, my_face['landmarks'])

plt.imshow(face_warped, cmap='gray')
plt.scatter(landmarks[:, 1], landmarks[:, 0], c='red', s=5)
plt.show()
